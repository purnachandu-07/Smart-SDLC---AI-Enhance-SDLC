# %% [markdown]
# # 🚀 Smart SDLC - AI Enhanced Software Development Lifecycle
# **Colab Launch Notebook**
#
# This notebook sets up and runs the full Smart SDLC project with all 8 AI-driven features using IBM Granite + Gradio in Google Colab.

# %%
# ✅ Step 1: Install required libraries - This step will be moved later to ensure installation in the correct directory.
# !pip install gradio transformers huggingface_hub langchain gitpython PyMuPDF nltk PyPDF2 -t /content/smart_sdlc/

# %%
# ✅ Step 2: Download NLTK sentence tokenizer
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# ✅ Step 3: Mount Google Drive to access the project files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ✅ Step 4: Navigate to the project directory (adjust path if needed)
# %cd /content/drive/MyDrive/smart_sdlc/modules
# Out:
# /content/drive/MyDrive/smart_sdlc/modules

# %%
import shutil

# Change this to your actual Drive folder name if different
source_path = "/content/drive/MyDrive/smart_sdlc"
destination_path = "/content/smart_sdlc"

shutil.copytree(source_path, destination_path)
print("✅ Project copied to /content/smart_sdlc")
# Out:
# ✅ Project copied to /content/smart_sdlc

# %%
# %cd /content/smart_sdlc/modules
# Out:
# /content/smart_sdlc/modules

# %%
import sys
sys.path.append('/content/smart_sdlc/')

try:
    import PyPDF2
    print("✅ PyPDF2 module imported successfully from /content/smart_sdlc/")
except ModuleNotFoundError:
    print("❌ PyPDF2 module not found in /content/smart_sdlc/. Please check the installation.")
# Out:
# ✅ PyPDF2 module imported successfully from /content/smart_sdlc/

# %%
# %run /content/smart_sdlc/modules/main_app.py

# %% [markdown]
# ---
# Created by **Hema Sundar Sai Ratnala**
# 🕒 Last generated: 2025-06-23 16:41:46
